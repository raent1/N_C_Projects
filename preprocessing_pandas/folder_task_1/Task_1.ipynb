# %% [markdown]
# # Задание 1

# %% [markdown]
# **Для каждой организации из main.csv подтяните выручку и число сотрудников за 2020, 2021 и 2022:**
# * посчитайте дельту по выручке и сотрудникам между 2022 и 2020;
# * отсортируйте организации по убыванию выручки. Для организаций с одинаковой выручкой выполните сортировку по возрастанию ID;
# * если у организации нет данных по выручке или числу сотрудников за 2020 или 2022, то исключите их;
# * названия колонок сделайте на русском языке.

# %% [markdown]
# ## Описание датасетов

# %% [markdown]
# #### main.csv - *основная информация о предприятиях*
# - ID - уникальный номер объекта;
# - Name - название;
# - Address - адрес
#
# #### net_property.csv - *указание на сетевые предприятия*
# - ID - уникальный номер объекта;
# - IsNetObject - метка сетевого предприятия;
#
# #### seats_property.csv - *количество посадочных мест*
# - ID - уникальный номер объекта;
# - SeatsCount - количество посадочных мест;
# - ver_ID - номер версии записи
#
# #### type_property.csv - *информация о специализации: столовая, закусочная, кафе, иное*
# - ID - уникальный номер объекта;
# - TypeObject - тип объекта;
# - is_actual - актуальность записи
#
# #### indicators_db.sqlite3 - *SQL-база с данными о выручке предприятий и числе сотрудников*
# - данные за 2019 г.;
# - данные за 2020-2022 гг.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Чтение датасетов

# %%
df1 = pd.read_csv('main.csv')
df2 = pd.read_csv('net_property.csv')
df3 = pd.read_csv('seats_property.csv')
df4 = pd.read_csv('type_property.csv')

# %%
import sqlalchemy as sql

# %%
con = sql.create_engine('sqlite:///indicators_db.sqlite3')

# %%
df = pd.read_sql("SELECT * FROM sqlite_master WHERE type='table';", con)

# %%
df
# Out:
#     type                      name                  tbl_name  rootpage  \
# 0  table       org_indicators_2019       org_indicators_2019         2
# 1  table  org_indicators_2020_2022  org_indicators_2020_2022       490
#
#                                                  sql
# 0  CREATE TABLE org_indicators_2019 (\r\n\tID BIG...
# 1  CREATE TABLE org_indicators_2020_2022 (\r\n\tI...

# %%
df_sql_select_20_22 = pd.read_sql('select * from org_indicators_2020_2022', con)

# %%
df_sql_select_20_22
# Out:
#             ID  YEAR     INDICATOR_NAME     VALUE
# 0        20988  2020            Выручка  29337447
# 1        20988  2020   Оценка на Яндекс         2
# 2        20988  2020             Налоги    720554
# 3        20988  2020     Оценка на 2GIS         3
# 4        24828  2020            Выручка  36633885
# ...        ...   ...                ...       ...
# 119995  339278  2022             Налоги    339380
# 119996   23511  2022  Число сотрудников        18
# 119997   23511  2022             Налоги    764187
# 119998   23511  2022            Выручка  22006160
# 119999   23511  2022     Оценка на 2GIS         1
#
# [120000 rows x 4 columns]

# %% [markdown]
# ### Выборка необходимых колонок из SQL-базы за 2020-2022 и разворот через pivot

# %%
df_20_22 = df_sql_select_20_22[(df_sql_select_20_22['INDICATOR_NAME'] == 'Число сотрудников') | \
                    (df_sql_select_20_22['INDICATOR_NAME']  == 'Выручка')]

# %%
df_20_22_piv = df_20_22.pivot(index = 'ID', columns = ['YEAR','INDICATOR_NAME'], values = 'VALUE')

# %%
df_20_22_piv
# Out:
# YEAR                  2020                          2021                    \
# INDICATOR_NAME     Выручка Число сотрудников     Выручка Число сотрудников
# ID
# 19630           31222228.0               NaN  21721921.0              15.0
# 19643           35670701.0              17.0  39125612.0               NaN
# 19647           34926614.0              16.0  23176004.0              15.0
# 19657           23410468.0               NaN  28065717.0               8.0
# 19677                  NaN              17.0  30803884.0               9.0
# ...                    ...               ...         ...               ...
# 375884                 NaN               8.0  32408516.0              10.0
# 375933          36102422.0               NaN  21245735.0              16.0
# 375954                 NaN              16.0         NaN               NaN
# 375956                 NaN               NaN  32178479.0               NaN
# 375960                 NaN              13.0  39567594.0               NaN
#
# YEAR                        2022
# INDICATOR_NAME Число сотрудников     Выручка
# ID
# 19630                        9.0         NaN
# 19643                        NaN         NaN
# 19647                        NaN  27925131.0
# 19657                       12.0  36074059.0
# 19677                        NaN  25303592.0
# ...                          ...         ...
# 375884                       7.0         NaN
# 375933                       NaN  39298414.0
# 375954                      11.0  20002278.0
# 375956                       6.0         NaN
# 375960                       NaN  37986011.0
#
# [10000 rows x 6 columns]

# %% [markdown]
# ### Удаление уровня "YEAR" и переименование колонок

# %%
testing = df_20_22_piv.droplevel([0], axis = 1)

# %%
testing.columns.names = [None]

# %%
testing.to_csv('test.csv')

# %%
testing = pd.read_csv('test.csv')

# %%
rename = {'Выручка':'Выручка 2020', 'Число сотрудников':'Число сотрудников 2020',
          'Выручка.1':'Выручка 2021', 'Число сотрудников.1':'Число сотрудников 2021',
          'Выручка.2':'Выручка 2022', 'Число сотрудников.2':'Число сотрудников 2022'}

# %%
testing = testing.rename(columns = rename)

# %%
testing
# Out:
#           ID  Выручка 2020  Число сотрудников 2020  Выручка 2021  \
# 0      19630    31222228.0                     NaN    21721921.0
# 1      19643    35670701.0                    17.0    39125612.0
# 2      19647    34926614.0                    16.0    23176004.0
# 3      19657    23410468.0                     NaN    28065717.0
# 4      19677           NaN                    17.0    30803884.0
# ...      ...           ...                     ...           ...
# 9995  375884           NaN                     8.0    32408516.0
# 9996  375933    36102422.0                     NaN    21245735.0
# 9997  375954           NaN                    16.0           NaN
# 9998  375956           NaN                     NaN    32178479.0
# 9999  375960           NaN                    13.0    39567594.0
#
#       Число сотрудников 2021  Число сотрудников 2022  Выручка 2022
# 0                       15.0                     9.0           NaN
# 1                        NaN                     NaN           NaN
# 2                       15.0                     NaN    27925131.0
# 3                        8.0                    12.0    36074059.0
# 4                        9.0                     NaN    25303592.0
# ...                      ...                     ...           ...
# 9995                    10.0                     7.0           NaN
# 9996                    16.0                     NaN    39298414.0
# 9997                     NaN                    11.0    20002278.0
# 9998                     NaN                     6.0           NaN
# 9999                     NaN                     NaN    37986011.0
#
# [10000 rows x 7 columns]

# %% [markdown]
# ### Вычисление дельты и изменение порядка колонок

# %%
testing['Дельта по выручке'] = testing['Выручка 2022'] - testing['Выручка 2020']
testing['Дельта по сотрудникам'] = testing['Число сотрудников 2022'] - testing['Число сотрудников 2020']

# %%
testing
# Out:
#           ID  Выручка 2020  Число сотрудников 2020  Выручка 2021  \
# 0      19630    31222228.0                     NaN    21721921.0
# 1      19643    35670701.0                    17.0    39125612.0
# 2      19647    34926614.0                    16.0    23176004.0
# 3      19657    23410468.0                     NaN    28065717.0
# 4      19677           NaN                    17.0    30803884.0
# ...      ...           ...                     ...           ...
# 9995  375884           NaN                     8.0    32408516.0
# 9996  375933    36102422.0                     NaN    21245735.0
# 9997  375954           NaN                    16.0           NaN
# 9998  375956           NaN                     NaN    32178479.0
# 9999  375960           NaN                    13.0    39567594.0
#
#       Число сотрудников 2021  Число сотрудников 2022  Выручка 2022  \
# 0                       15.0                     9.0           NaN
# 1                        NaN                     NaN           NaN
# 2                       15.0                     NaN    27925131.0
# 3                        8.0                    12.0    36074059.0
# 4                        9.0                     NaN    25303592.0
# ...                      ...                     ...           ...
# 9995                    10.0                     7.0           NaN
# 9996                    16.0                     NaN    39298414.0
# 9997                     NaN                    11.0    20002278.0
# 9998                     NaN                     6.0           NaN
# 9999                     NaN                     NaN    37986011.0
#
#       Дельта по выручке  Дельта по сотрудникам
# 0                   NaN                    NaN
# 1                   NaN                    NaN
# 2            -7001483.0                    NaN
# 3            12663591.0                    NaN
# 4                   NaN                    NaN
# ...                 ...                    ...
# 9995                NaN                   -1.0
# 9996          3195992.0                    NaN
# 9997                NaN                   -5.0
# 9998                NaN                    NaN
# 9999                NaN                    NaN
#
# [10000 rows x 9 columns]

# %% [markdown]
# ### Удаление пропусков и лишних колонок в годах 2020 и 2022, полученных в ходе объединения

# %%
mask = testing[['ID','Выручка 2020','Выручка 2022', 'Число сотрудников 2020','Число сотрудников 2022']].dropna()

# %%
merge_testing = pd.merge(mask, testing, how = 'inner', on = 'ID')

# %%
merge_testing
# Out:
#           ID  Выручка 2020_x  Выручка 2022_x  Число сотрудников 2020_x  \
# 0      19726      34342910.0      37135202.0                      11.0
# 1      19727      26257455.0      38039622.0                       8.0
# 2      19741      26616852.0      27339029.0                      11.0
# 3      19823      27222724.0      22123140.0                      12.0
# 4      19939      34539627.0      25711365.0                      12.0
# ...      ...             ...             ...                       ...
# 1581  375289      27078398.0      28646290.0                      13.0
# 1582  375352      31787477.0      37116392.0                      11.0
# 1583  375629      26926434.0      29411964.0                      14.0
# 1584  375654      35269880.0      35309041.0                      18.0
# 1585  375834      32599139.0      27788474.0                      19.0
#
#       Число сотрудников 2022_x  Выручка 2020_y  Выручка 2021  Выручка 2022_y  \
# 0                          8.0      34342910.0    39073727.0      37135202.0
# 1                         11.0      26257455.0    27300658.0      38039622.0
# 2                         14.0      26616852.0    33580915.0      27339029.0
# 3                         10.0      27222724.0    30561355.0      22123140.0
# 4                         18.0      34539627.0           NaN      25711365.0
# ...                        ...             ...           ...             ...
# 1581                       7.0      27078398.0    34867524.0      28646290.0
# 1582                      13.0      31787477.0           NaN      37116392.0
# 1583                      11.0      26926434.0    24479012.0      29411964.0
# 1584                      13.0      35269880.0    24593454.0      35309041.0
# 1585                      19.0      32599139.0    30046613.0      27788474.0
#
#       Дельта по выручке  Число сотрудников 2020_y  Число сотрудников 2021  \
# 0             2792292.0                      11.0                     8.0
# 1            11782167.0                       8.0                     NaN
# 2              722177.0                      11.0                    12.0
# 3            -5099584.0                      12.0                     NaN
# 4            -8828262.0                      12.0                    12.0
# ...                 ...                       ...                     ...
# 1581          1567892.0                      13.0                     NaN
# 1582          5328915.0                      11.0                    15.0
# 1583          2485530.0                      14.0                    12.0
# 1584            39161.0                      18.0                    13.0
# 1585         -4810665.0                      19.0                     8.0
#
#       Число сотрудников 2022_y  Дельта по сотрудникам
# 0                          8.0                   -3.0
# 1                         11.0                    3.0
# 2                         14.0                    3.0
# 3                         10.0                   -2.0
# 4                         18.0                    6.0
# ...                        ...                    ...
# 1581                       7.0                   -6.0
# 1582                      13.0                    2.0
# 1583                      11.0                   -3.0
# 1584                      13.0                   -5.0
# 1585                      19.0                    0.0
#
# [1586 rows x 13 columns]

# %%
merge_testing.drop(['Выручка 2020_y', 'Выручка 2022_y',
                    'Число сотрудников 2020_y','Число сотрудников 2022_y'], axis = 1, inplace = True)

# %%
merge_testing
# Out:
#           ID  Выручка 2020_x  Выручка 2022_x  Число сотрудников 2020_x  \
# 0      19726      34342910.0      37135202.0                      11.0
# 1      19727      26257455.0      38039622.0                       8.0
# 2      19741      26616852.0      27339029.0                      11.0
# 3      19823      27222724.0      22123140.0                      12.0
# 4      19939      34539627.0      25711365.0                      12.0
# ...      ...             ...             ...                       ...
# 1581  375289      27078398.0      28646290.0                      13.0
# 1582  375352      31787477.0      37116392.0                      11.0
# 1583  375629      26926434.0      29411964.0                      14.0
# 1584  375654      35269880.0      35309041.0                      18.0
# 1585  375834      32599139.0      27788474.0                      19.0
#
#       Число сотрудников 2022_x  Выручка 2021  Дельта по выручке  \
# 0                          8.0    39073727.0          2792292.0
# 1                         11.0    27300658.0         11782167.0
# 2                         14.0    33580915.0           722177.0
# 3                         10.0    30561355.0         -5099584.0
# 4                         18.0           NaN         -8828262.0
# ...                        ...           ...                ...
# 1581                       7.0    34867524.0          1567892.0
# 1582                      13.0           NaN          5328915.0
# 1583                      11.0    24479012.0          2485530.0
# 1584                      13.0    24593454.0            39161.0
# 1585                      19.0    30046613.0         -4810665.0
#
#       Число сотрудников 2021  Дельта по сотрудникам
# 0                        8.0                   -3.0
# 1                        NaN                    3.0
# 2                       12.0                    3.0
# 3                        NaN                   -2.0
# 4                       12.0                    6.0
# ...                      ...                    ...
# 1581                     NaN                   -6.0
# 1582                    15.0                    2.0
# 1583                    12.0                   -3.0
# 1584                    13.0                   -5.0
# 1585                     8.0                    0.0
#
# [1586 rows x 9 columns]

# %%
rename_2 = {'Выручка 2020_x':'Выручка 2020',
            'Выручка 2022_x':'Выручка 2022',
            'Число сотрудников 2020_x':'Число сотрудников 2020',
            'Число сотрудников 2022_x':'Число сотрудников 2022'}
merge_testing = merge_testing.rename(columns = rename_2)

# %%
merge_testing = merge_testing[['ID','Выручка 2020','Выручка 2021','Выручка 2022', 'Дельта по выручке',
         'Число сотрудников 2020','Число сотрудников 2021','Число сотрудников 2022', 'Дельта по сотрудникам']]

# %%
merge_testing
# Out:
#           ID  Выручка 2020  Выручка 2021  Выручка 2022  Дельта по выручке  \
# 0      19726    34342910.0    39073727.0    37135202.0          2792292.0
# 1      19727    26257455.0    27300658.0    38039622.0         11782167.0
# 2      19741    26616852.0    33580915.0    27339029.0           722177.0
# 3      19823    27222724.0    30561355.0    22123140.0         -5099584.0
# 4      19939    34539627.0           NaN    25711365.0         -8828262.0
# ...      ...           ...           ...           ...                ...
# 1581  375289    27078398.0    34867524.0    28646290.0          1567892.0
# 1582  375352    31787477.0           NaN    37116392.0          5328915.0
# 1583  375629    26926434.0    24479012.0    29411964.0          2485530.0
# 1584  375654    35269880.0    24593454.0    35309041.0            39161.0
# 1585  375834    32599139.0    30046613.0    27788474.0         -4810665.0
#
#       Число сотрудников 2020  Число сотрудников 2021  Число сотрудников 2022  \
# 0                       11.0                     8.0                     8.0
# 1                        8.0                     NaN                    11.0
# 2                       11.0                    12.0                    14.0
# 3                       12.0                     NaN                    10.0
# 4                       12.0                    12.0                    18.0
# ...                      ...                     ...                     ...
# 1581                    13.0                     NaN                     7.0
# 1582                    11.0                    15.0                    13.0
# 1583                    14.0                    12.0                    11.0
# 1584                    18.0                    13.0                    13.0
# 1585                    19.0                     8.0                    19.0
#
#       Дельта по сотрудникам
# 0                      -3.0
# 1                       3.0
# 2                       3.0
# 3                      -2.0
# 4                       6.0
# ...                     ...
# 1581                   -6.0
# 1582                    2.0
# 1583                   -3.0
# 1584                   -5.0
# 1585                    0.0
#
# [1586 rows x 9 columns]

# %%
sorted_testing = merge_testing.sort_values(by = 'Дельта по выручке', ascending = False)

# %% [markdown]
# ### Добавление основного датасета, переименование и сохранение

# %%
df_testing = pd.merge(df1,sorted_testing, on = 'ID', how = 'inner')

# %%
rename_3 = {'ID':'Идентификатор',
            'Name':'Наименование',
            'Address':'Адрес'}
df_testing = df_testing.rename(columns = rename_3)

# %%
df_test_sort = df_testing.sort_values(by = 'Дельта по выручке', ascending = False)

# %%
df_test_sort.to_csv('final.csv', index=False)

# %% [markdown]
# ### Проверка результирующего датасета

# %%
pd.read_csv('final.csv')
# Out:
#       Идентификатор                Наименование  \
# 0            342920  СИДРОВ ПРОЛИВ (пивной бар)
# 1            374427                 Море лосося
# 2            360584             Выпечка, шаурма
# 3            344731                Кофе с собой
# 4            373914                        Кафе
# ...             ...                         ...
# 1581         129686                 Три правила
# 1582         344859               Хлеб с маслом
# 1583         150865                    Lost Bar
# 1584         239777                 Surf Coffee
# 1585          29019                   ШКОЛА 878
#
#                                                   Адрес  Выручка 2020  \
# 0           город Москва, проспект Вернадского, дом 86В    20302399.0
# 1     город Москва, улица Адмирала Макарова, дом 6, ...    20000135.0
# 2     Российская Федерация, город Москва, внутригоро...    20114682.0
# 3     Российская Федерация, город Москва, внутригоро...    21020009.0
# 4     город Москва, улица Айвазовского, владение 7, ...    20663231.0
# ...                                                 ...           ...
# 1581  город Москва, улица Мичуринский Проспект, Олим...    39778987.0
# 1582  город Москва, Манежная площадь, дом 1, строение 2    38772086.0
# 1583          город Москва, Новокосинская улица, дом 22    39338589.0
# 1584  город Москва, Берсеневская набережная, дом 14,...    39515097.0
# 1585  город Москва, Шипиловский проезд, дом 37, корп...    39281579.0
#
#       Выручка 2021  Выручка 2022  Дельта по выручке  Число сотрудников 2020  \
# 0              NaN    39959846.0         19657447.0                     6.0
# 1              NaN    39484937.0         19484802.0                     7.0
# 2       23403344.0    39418028.0         19303346.0                    13.0
# 3       39682516.0    39851594.0         18831585.0                     8.0
# 4       31079091.0    38834892.0         18171661.0                     7.0
# ...            ...           ...                ...                     ...
# 1581           NaN    21141214.0        -18637773.0                    15.0
# 1582           NaN    20065466.0        -18706620.0                    13.0
# 1583    34587746.0    20463995.0        -18874594.0                    15.0
# 1584    28540582.0    20432343.0        -19082754.0                    19.0
# 1585           NaN    20088881.0        -19192698.0                    18.0
#
#       Число сотрудников 2021  Число сотрудников 2022  Дельта по сотрудникам
# 0                       11.0                    14.0                    8.0
# 1                        NaN                    19.0                   12.0
# 2                        NaN                    11.0                   -2.0
# 3                        NaN                    10.0                    2.0
# 4                       16.0                    14.0                    7.0
# ...                      ...                     ...                    ...
# 1581                    17.0                     8.0                   -7.0
# 1582                     8.0                    15.0                    2.0
# 1583                    18.0                    15.0                    0.0
# 1584                     NaN                     9.0                  -10.0
# 1585                    17.0                    19.0                    1.0
#
# [1586 rows x 11 columns]
